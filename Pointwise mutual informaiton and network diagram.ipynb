# %% [markdown]
# # Load data from DB

# %%
import mysql.connector
import pandas as pd

db = mysql.connector.connect(host='localhost',user='root',password='root', database='food_recommendation')

# %%
df = pd.read_sql(("""

SELECT ing.ingredient_name, recipe_id FROM food_recommendation.ingredients ing
JOIN food_recommendation.recipe_ingredients ri
ON ing.ingredient_id = ri.ingredient_id
ORDER BY recipe_id

"""), db)

# %%
df
# Out:
#               ingredient_name  recipe_id
# 0          white wine vinegar        415
# 1             salt and pepper        415
# 2          low fat sour cream        415
# 3                  buttermilk        415
# 4              fresh tarragon        415
# ...                       ...        ...
# 10809  unsweetened applesauce     999602
# 10810             baking soda     999602
# 10811             maple syrup     999602
# 10812               oat flour     999602
# 10813           hazelnut meal     999602
#
# [10814 rows x 2 columns]

# %% [markdown]
# # Concat ingredients in to a single string

# %%
df['recipe_id'].unique()
# Out:
# array([   415,    860,    896, ..., 998213, 999278, 999602], dtype=int64)

# %%
df.groupby('recipe_id').transform(lambda x: ','.join(x))
# Out:
#                                          ingredient_name
# 0      white wine vinegar,salt and pepper,low fat sou...
# 1      white wine vinegar,salt and pepper,low fat sou...
# 2      white wine vinegar,salt and pepper,low fat sou...
# 3      white wine vinegar,salt and pepper,low fat sou...
# 4      white wine vinegar,salt and pepper,low fat sou...
# ...                                                  ...
# 10809  milk,eggs,salt,vanilla,unsweetened applesauce,...
# 10810  milk,eggs,salt,vanilla,unsweetened applesauce,...
# 10811  milk,eggs,salt,vanilla,unsweetened applesauce,...
# 10812  milk,eggs,salt,vanilla,unsweetened applesauce,...
# 10813  milk,eggs,salt,vanilla,unsweetened applesauce,...
#
# [10814 rows x 1 columns]

# %%
df_recipe_ingredients = df.groupby('recipe_id')['ingredient_name'].transform(lambda x: ','.join(x)).drop_duplicates()
df_recipe_ingredients
# Out:
# 0        white wine vinegar,salt and pepper,low fat sou...
# 15       capers,olive oil,shallots,red wine vinegar,kos...
# 22       coarse salt,blood oranges,green olives,unsalte...
# 29       oregano,paprika,olive oil,garlic clove,onion,r...
# 41       sea-salt,roma tomatoes,feta cheese,fresh dill,...
#                                ...
# 10764    butter,cream cheese,heavy cream,salt,vanilla,s...
# 10774    honey,plain greek yogurt,red onion,poppy seeds...
# 10785    parmesan cheese,salt,olive oil,dried cranberri...
# 10793    vanilla ice cream,brown sugar,flour,kosher sal...
# 10805    milk,eggs,salt,vanilla,unsweetened applesauce,...
# Name: ingredient_name, Length: 1107, dtype: object

# %% [markdown]
# # Add ID back in DF

# %%
df_recipe_ingredients= pd.DataFrame(list(zip(df['recipe_id'].unique(), df_recipe_ingredients.to_list())), columns = ['id','ingredients'])
df_recipe_ingredients
# Out:
#           id                                        ingredients
# 0        415  white wine vinegar,salt and pepper,low fat sou...
# 1        860  capers,olive oil,shallots,red wine vinegar,kos...
# 2        896  coarse salt,blood oranges,green olives,unsalte...
# 3       3131  oregano,paprika,olive oil,garlic clove,onion,r...
# 4       3642  sea-salt,roma tomatoes,feta cheese,fresh dill,...
# ...      ...                                                ...
# 1102  993892  butter,cream cheese,heavy cream,salt,vanilla,s...
# 1103  996399  honey,plain greek yogurt,red onion,poppy seeds...
# 1104  998213  parmesan cheese,salt,olive oil,dried cranberri...
# 1105  999278  vanilla ice cream,brown sugar,flour,kosher sal...
# 1106  999602  milk,eggs,salt,vanilla,unsweetened applesauce,...
#
# [1107 rows x 2 columns]

# %% [markdown]
# # Initialise df to store PMI

# %%
ingredients = df['ingredient_name'].unique()
df_pmi = pd.DataFrame(index = ingredients, columns = ingredients)
df_pmi.fillna(0, inplace = True)
df_pmi
# Out:
#                         white wine vinegar  salt and pepper  \
# white wine vinegar                       0                0
# salt and pepper                          0                0
# low fat sour cream                       0                0
# buttermilk                               0                0
# fresh tarragon                           0                0
# ...                                    ...              ...
# potato flakes                            0                0
# 85 percent ground beef                   0                0
# queso dip                                0                0
# erythritol                               0                0
# hazelnut meal                            0                0
#
#                         low fat sour cream  buttermilk  fresh tarragon  \
# white wine vinegar                       0           0               0
# salt and pepper                          0           0               0
# low fat sour cream                       0           0               0
# buttermilk                               0           0               0
# fresh tarragon                           0           0               0
# ...                                    ...         ...             ...
# potato flakes                            0           0               0
# 85 percent ground beef                   0           0               0
# queso dip                                0           0               0
# erythritol                               0           0               0
# hazelnut meal                            0           0               0
#
#                         olive oil  low fat mayonnaise  chicken breasts  \
# white wine vinegar              0                   0                0
# salt and pepper                 0                   0                0
# low fat sour cream              0                   0                0
# buttermilk                      0                   0                0
# fresh tarragon                  0                   0                0
# ...                           ...                 ...              ...
# potato flakes                   0                   0                0
# 85 percent ground beef          0                   0                0
# queso dip                       0                   0                0
# erythritol                      0                   0                0
# hazelnut meal                   0                   0                0
#
#                         avocado  chives  ...  rooibos  low sodium beef broth  \
# white wine vinegar            0       0  ...        0                      0
# salt and pepper               0       0  ...        0                      0
# low fat sour cream            0       0  ...        0                      0
# buttermilk                    0       0  ...        0                      0
# fresh tarragon                0       0  ...        0                      0
# ...                         ...     ...  ...      ...                    ...
# potato flakes                 0       0  ...        0                      0
# 85 percent ground beef        0       0  ...        0                      0
# queso dip                     0       0  ...        0                      0
# erythritol                    0       0  ...        0                      0
# hazelnut meal                 0       0  ...        0                      0
#
#                         cooked macaroni pasta  tempeh  canned beans  \
# white wine vinegar                          0       0             0
# salt and pepper                             0       0             0
# low fat sour cream                          0       0             0
# buttermilk                                  0       0             0
# fresh tarragon                              0       0             0
# ...                                       ...     ...           ...
# potato flakes                               0       0             0
# 85 percent ground beef                      0       0             0
# queso dip                                   0       0             0
# erythritol                                  0       0             0
# hazelnut meal                               0       0             0
#
#                         potato flakes  85 percent ground beef  queso dip  \
# white wine vinegar                  0                       0          0
# salt and pepper                     0                       0          0
# low fat sour cream                  0                       0          0
# buttermilk                          0                       0          0
# fresh tarragon                      0                       0          0
# ...                               ...                     ...        ...
# potato flakes                       0                       0          0
# 85 percent ground beef              0                       0          0
# queso dip                           0                       0          0
# erythritol                          0                       0          0
# hazelnut meal                       0                       0          0
#
#                         erythritol  hazelnut meal
# white wine vinegar               0              0
# salt and pepper                  0              0
# low fat sour cream               0              0
# buttermilk                       0              0
# fresh tarragon                   0              0
# ...                            ...            ...
# potato flakes                    0              0
# 85 percent ground beef           0              0
# queso dip                        0              0
# erythritol                       0              0
# hazelnut meal                    0              0
#
# [1231 rows x 1231 columns]

# %% [markdown]
# # Count the occurence of ingredients in the same recipe and compute PMI
#
# \\[    \frac{p(ab)}{p(a)p(b)}      \\]

# %%
for i in range(len(df_recipe_ingredients['ingredients'])):
    list_of_ingredients = df_recipe_ingredients['ingredients'][i].split(',')
    for j in range(len(list_of_ingredients)-1):
        for k in range(j+1, len(list_of_ingredients)):
            df_pmi.loc[list_of_ingredients[j], list_of_ingredients[k]] +=1
            df_pmi.loc[list_of_ingredients[k], list_of_ingredients[j]] +=1

# %%
df_pmi
# Out:
#                         white wine vinegar  salt and pepper  \
# white wine vinegar                       0                1
# salt and pepper                          1                0
# low fat sour cream                       1                1
# buttermilk                               1                1
# fresh tarragon                           2                2
# ...                                    ...              ...
# potato flakes                            0                1
# 85 percent ground beef                   0                1
# queso dip                                0                1
# erythritol                               0                0
# hazelnut meal                            0                0
#
#                         low fat sour cream  buttermilk  fresh tarragon  \
# white wine vinegar                       1           1               2
# salt and pepper                          1           1               2
# low fat sour cream                       0           1               1
# buttermilk                               1           0               2
# fresh tarragon                           1           2               0
# ...                                    ...         ...             ...
# potato flakes                            0           0               0
# 85 percent ground beef                   0           0               0
# queso dip                                0           0               0
# erythritol                               0           0               0
# hazelnut meal                            0           0               0
#
#                         olive oil  low fat mayonnaise  chicken breasts  \
# white wine vinegar              4                   1                1
# salt and pepper                41                   2                5
# low fat sour cream              1                   1                1
# buttermilk                      4                   1                1
# fresh tarragon                  6                   1                2
# ...                           ...                 ...              ...
# potato flakes                   0                   0                0
# 85 percent ground beef          0                   0                0
# queso dip                       0                   0                1
# erythritol                      0                   0                0
# hazelnut meal                   0                   0                0
#
#                         avocado  chives  ...  rooibos  low sodium beef broth  \
# white wine vinegar            1       1  ...        0                      0
# salt and pepper               5       6  ...        0                      0
# low fat sour cream            1       1  ...        0                      0
# buttermilk                    3       2  ...        0                      0
# fresh tarragon                1       1  ...        0                      0
# ...                         ...     ...  ...      ...                    ...
# potato flakes                 0       0  ...        0                      0
# 85 percent ground beef        0       0  ...        0                      0
# queso dip                     0       0  ...        0                      0
# erythritol                    0       0  ...        0                      0
# hazelnut meal                 0       0  ...        0                      0
#
#                         cooked macaroni pasta  tempeh  canned beans  \
# white wine vinegar                          0       0             0
# salt and pepper                             1       0             0
# low fat sour cream                          0       0             0
# buttermilk                                  0       1             0
# fresh tarragon                              0       0             0
# ...                                       ...     ...           ...
# potato flakes                               0       0             0
# 85 percent ground beef                      0       0             0
# queso dip                                   0       0             0
# erythritol                                  0       0             0
# hazelnut meal                               0       0             0
#
#                         potato flakes  85 percent ground beef  queso dip  \
# white wine vinegar                  0                       0          0
# salt and pepper                     1                       1          1
# low fat sour cream                  0                       0          0
# buttermilk                          0                       0          0
# fresh tarragon                      0                       0          0
# ...                               ...                     ...        ...
# potato flakes                       0                       1          0
# 85 percent ground beef              1                       0          0
# queso dip                           0                       0          0
# erythritol                          0                       0          0
# hazelnut meal                       0                       0          0
#
#                         erythritol  hazelnut meal
# white wine vinegar               0              0
# salt and pepper                  0              0
# low fat sour cream               0              0
# buttermilk                       0              0
# fresh tarragon                   0              0
# ...                            ...            ...
# potato flakes                    0              0
# 85 percent ground beef           0              0
# queso dip                        0              0
# erythritol                       0              0
# hazelnut meal                    0              0
#
# [1231 rows x 1231 columns]

# %%
df_pmi.astype('int32').dtypes
# Out:
# white wine vinegar        int32
# salt and pepper           int32
# low fat sour cream        int32
# buttermilk                int32
# fresh tarragon            int32
#                           ...
# potato flakes             int32
# 85 percent ground beef    int32
# queso dip                 int32
# erythritol                int32
# hazelnut meal             int32
# Length: 1231, dtype: object

# %%
import math

def pmi(list_of_ingredients, count_matrix):
    pmi_list = []
    ingredient_pair = []
    for i in range(len(list_of_ingredients)-1):
        for j in range(i+1, len(list_of_ingredients)):
            pa = sum(count_matrix[list_of_ingredients[i]]) 
            pb = sum(count_matrix[list_of_ingredients[j]]) 
            pab = count_matrix.loc[list_of_ingredients[i], list_of_ingredients[j]]
            pmi = pab/(pa*pb)
            pmi_list.append(pmi)
            ingredient_pair.append(list_of_ingredients[i] + '_' + list_of_ingredients[j])
    
    
    
    return  pmi_list

# %%
p = pmi(df_recipe_ingredients['ingredients'][1].split(','), df_pmi )

# %%
p
# Out:
# [2.5049203793165147e-05,
#  6.57102179388895e-05,
#  0.00011645962732919254,
#  1.642238370899536e-05,
#  4.675081813931744e-05,
#  0.0005797101449275362,
#  2.176819976987903e-05,
#  2.9394473838918284e-05,
#  1.5932415470764017e-05,
#  1.1062436390990752e-05,
#  2.7434842249657064e-05,
#  2.24901043540842e-05,
#  1.6649897840983963e-05,
#  2.7084856856531512e-05,
#  0.00016792611251049538,
#  1.686226898691488e-05,
#  2.4001536098310292e-05,
#  0.00029761904761904765,
#  1.0153624336206809e-05,
#  0.00012590494176896444,
#  0.00035842293906810036]

# %%
import numpy as np

max_pmi = []
min_pmi = []
avg_pmi = []

for i in range(len(df_recipe_ingredients)):
    p = pmi(df_recipe_ingredients['ingredients'][i].split(','), df_pmi )
    if len(p) == 0:
        
        max_pmi.append(None)
        min_pmi.append(None)
        avg_pmi.append(None)
    else:
        max_pmi.append(max(p))
        min_pmi.append(min(p))
        avg_pmi.append(np.mean(p))

# %%
df_recipe_ingredients['max_pmi'] = max_pmi
df_recipe_ingredients['min_pmi'] = min_pmi
df_recipe_ingredients['avg_pmi'] = avg_pmi
df_recipe_ingredients
# Out:
#           id                                        ingredients   max_pmi  \
# 0        415  white wine vinegar,salt and pepper,low fat sou...  0.000611
# 1        860  capers,olive oil,shallots,red wine vinegar,kos...  0.000580
# 2        896  coarse salt,blood oranges,green olives,unsalte...  0.000461
# 3       3131  oregano,paprika,olive oil,garlic clove,onion,r...  0.000407
# 4       3642  sea-salt,roma tomatoes,feta cheese,fresh dill,...  0.000123
# ...      ...                                                ...       ...
# 1102  993892  butter,cream cheese,heavy cream,salt,vanilla,s...  0.002268
# 1103  996399  honey,plain greek yogurt,red onion,poppy seeds...  0.000439
# 1104  998213  parmesan cheese,salt,olive oil,dried cranberri...  0.000316
# 1105  999278  vanilla ice cream,brown sugar,flour,kosher sal...  0.000220
# 1106  999602  milk,eggs,salt,vanilla,unsweetened applesauce,...  0.006944
#
#        min_pmi   avg_pmi
# 0     0.000004  0.000083
# 1     0.000010  0.000096
# 2     0.000006  0.000100
# 3     0.000008  0.000038
# 4     0.000006  0.000030
# ...        ...       ...
# 1102  0.000007  0.000188
# 1103  0.000008  0.000080
# 1104  0.000005  0.000038
# 1105  0.000005  0.000035
# 1106  0.000011  0.000305
#
# [1107 rows x 5 columns]

# %%
df_pmi
# Out:
#                         white wine vinegar  salt and pepper  \
# white wine vinegar                       0                1
# salt and pepper                          1                0
# low fat sour cream                       1                1
# buttermilk                               1                1
# fresh tarragon                           2                2
# ...                                    ...              ...
# potato flakes                            0                1
# 85 percent ground beef                   0                1
# queso dip                                0                1
# erythritol                               0                0
# hazelnut meal                            0                0
#
#                         low fat sour cream  buttermilk  fresh tarragon  \
# white wine vinegar                       1           1               2
# salt and pepper                          1           1               2
# low fat sour cream                       0           1               1
# buttermilk                               1           0               2
# fresh tarragon                           1           2               0
# ...                                    ...         ...             ...
# potato flakes                            0           0               0
# 85 percent ground beef                   0           0               0
# queso dip                                0           0               0
# erythritol                               0           0               0
# hazelnut meal                            0           0               0
#
#                         olive oil  low fat mayonnaise  chicken breasts  \
# white wine vinegar              4                   1                1
# salt and pepper                41                   2                5
# low fat sour cream              1                   1                1
# buttermilk                      4                   1                1
# fresh tarragon                  6                   1                2
# ...                           ...                 ...              ...
# potato flakes                   0                   0                0
# 85 percent ground beef          0                   0                0
# queso dip                       0                   0                1
# erythritol                      0                   0                0
# hazelnut meal                   0                   0                0
#
#                         avocado  chives  ...  rooibos  low sodium beef broth  \
# white wine vinegar            1       1  ...        0                      0
# salt and pepper               5       6  ...        0                      0
# low fat sour cream            1       1  ...        0                      0
# buttermilk                    3       2  ...        0                      0
# fresh tarragon                1       1  ...        0                      0
# ...                         ...     ...  ...      ...                    ...
# potato flakes                 0       0  ...        0                      0
# 85 percent ground beef        0       0  ...        0                      0
# queso dip                     0       0  ...        0                      0
# erythritol                    0       0  ...        0                      0
# hazelnut meal                 0       0  ...        0                      0
#
#                         cooked macaroni pasta  tempeh  canned beans  \
# white wine vinegar                          0       0             0
# salt and pepper                             1       0             0
# low fat sour cream                          0       0             0
# buttermilk                                  0       1             0
# fresh tarragon                              0       0             0
# ...                                       ...     ...           ...
# potato flakes                               0       0             0
# 85 percent ground beef                      0       0             0
# queso dip                                   0       0             0
# erythritol                                  0       0             0
# hazelnut meal                               0       0             0
#
#                         potato flakes  85 percent ground beef  queso dip  \
# white wine vinegar                  0                       0          0
# salt and pepper                     1                       1          1
# low fat sour cream                  0                       0          0
# buttermilk                          0                       0          0
# fresh tarragon                      0                       0          0
# ...                               ...                     ...        ...
# potato flakes                       0                       1          0
# 85 percent ground beef              1                       0          0
# queso dip                           0                       0          0
# erythritol                          0                       0          0
# hazelnut meal                       0                       0          0
#
#                         erythritol  hazelnut meal
# white wine vinegar               0              0
# salt and pepper                  0              0
# low fat sour cream               0              0
# buttermilk                       0              0
# fresh tarragon                   0              0
# ...                            ...            ...
# potato flakes                    0              0
# 85 percent ground beef           0              0
# queso dip                        0              0
# erythritol                       0              0
# hazelnut meal                    0              0
#
# [1231 rows x 1231 columns]

# %% [markdown]
# # Calculate PMI for each pair of ingredients

# %%
recipe_pmi = pd.DataFrame(index = ingredients, columns = ingredients)
recipe_pmi.fillna(0, inplace = True)
recipe_pmi
# Out:
#                         white wine vinegar  salt and pepper  \
# white wine vinegar                       0                0
# salt and pepper                          0                0
# low fat sour cream                       0                0
# buttermilk                               0                0
# fresh tarragon                           0                0
# ...                                    ...              ...
# potato flakes                            0                0
# 85 percent ground beef                   0                0
# queso dip                                0                0
# erythritol                               0                0
# hazelnut meal                            0                0
#
#                         low fat sour cream  buttermilk  fresh tarragon  \
# white wine vinegar                       0           0               0
# salt and pepper                          0           0               0
# low fat sour cream                       0           0               0
# buttermilk                               0           0               0
# fresh tarragon                           0           0               0
# ...                                    ...         ...             ...
# potato flakes                            0           0               0
# 85 percent ground beef                   0           0               0
# queso dip                                0           0               0
# erythritol                               0           0               0
# hazelnut meal                            0           0               0
#
#                         olive oil  low fat mayonnaise  chicken breasts  \
# white wine vinegar              0                   0                0
# salt and pepper                 0                   0                0
# low fat sour cream              0                   0                0
# buttermilk                      0                   0                0
# fresh tarragon                  0                   0                0
# ...                           ...                 ...              ...
# potato flakes                   0                   0                0
# 85 percent ground beef          0                   0                0
# queso dip                       0                   0                0
# erythritol                      0                   0                0
# hazelnut meal                   0                   0                0
#
#                         avocado  chives  ...  rooibos  low sodium beef broth  \
# white wine vinegar            0       0  ...        0                      0
# salt and pepper               0       0  ...        0                      0
# low fat sour cream            0       0  ...        0                      0
# buttermilk                    0       0  ...        0                      0
# fresh tarragon                0       0  ...        0                      0
# ...                         ...     ...  ...      ...                    ...
# potato flakes                 0       0  ...        0                      0
# 85 percent ground beef        0       0  ...        0                      0
# queso dip                     0       0  ...        0                      0
# erythritol                    0       0  ...        0                      0
# hazelnut meal                 0       0  ...        0                      0
#
#                         cooked macaroni pasta  tempeh  canned beans  \
# white wine vinegar                          0       0             0
# salt and pepper                             0       0             0
# low fat sour cream                          0       0             0
# buttermilk                                  0       0             0
# fresh tarragon                              0       0             0
# ...                                       ...     ...           ...
# potato flakes                               0       0             0
# 85 percent ground beef                      0       0             0
# queso dip                                   0       0             0
# erythritol                                  0       0             0
# hazelnut meal                               0       0             0
#
#                         potato flakes  85 percent ground beef  queso dip  \
# white wine vinegar                  0                       0          0
# salt and pepper                     0                       0          0
# low fat sour cream                  0                       0          0
# buttermilk                          0                       0          0
# fresh tarragon                      0                       0          0
# ...                               ...                     ...        ...
# potato flakes                       0                       0          0
# 85 percent ground beef              0                       0          0
# queso dip                           0                       0          0
# erythritol                          0                       0          0
# hazelnut meal                       0                       0          0
#
#                         erythritol  hazelnut meal
# white wine vinegar               0              0
# salt and pepper                  0              0
# low fat sour cream               0              0
# buttermilk                       0              0
# fresh tarragon                   0              0
# ...                            ...            ...
# potato flakes                    0              0
# 85 percent ground beef           0              0
# queso dip                        0              0
# erythritol                       0              0
# hazelnut meal                    0              0
#
# [1231 rows x 1231 columns]

# %%
sum_dict = {}
for i in ingredients:
    sum_dict[i] = df_pmi[i].sum()

# %%
sum_dict
# Out:
# {'white wine vinegar': 52,
#  'salt and pepper': 928,
#  'low fat sour cream': 42,
#  'buttermilk': 297,
#  'fresh tarragon': 105,
#  'olive oil': 2430,
#  'low fat mayonnaise': 52,
#  'chicken breasts': 142,
#  'avocado': 370,
#  'chives': 218,
#  'cucumber': 248,
#  'fresh parsley': 978,
#  'tomato': 841,
#  'arugula': 105,
#  'anchovy': 39,
#  'capers': 115,
#  'shallots': 397,
#  'red wine vinegar': 224,
#  'kosher salt': 1059,
#  'spinach': 186,
#  'striped bass': 15,
#  'coarse salt': 87,
#  'blood oranges': 35,
#  'green olives': 62,
#  'unsalted butter': 1053,
#  'canola oil': 644,
#  'cod fillets': 78,
#  'oregano': 561,
#  'paprika': 227,
#  'garlic clove': 3247,
#  'onion': 1936,
#  'red bell peppers': 486,
#  'fennel': 142,
#  'white wine': 388,
#  'herbs': 60,
#  'canned tomatoes': 405,
#  'fish': 41,
#  'sea-salt': 521,
#  'roma tomatoes': 77,
#  'feta cheese': 229,
#  'fresh dill': 177,
#  'zucchini': 173,
#  'sour cream': 420,
#  'vegetable oil': 545,
#  'limes': 91,
#  'lime juice': 598,
#  'lettuce': 159,
#  'mahi mahi': 19,
#  'corn tortillas': 142,
#  'pico de gallo': 17,
#  'granulated sugar': 2710,
#  'mat beans': 38,
#  'plum tomatoes': 83,
#  'egg yolk': 210,
#  'salt': 3932,
#  'fish stock': 14,
#  'pears': 93,
#  'fresh green beans': 108,
#  'snow peas': 41,
#  'potato': 362,
#  'monkfish': 14,
#  'orange juice': 278,
#  'orange peel': 188,
#  'salmon filets': 101,
#  'low sodium soy sauce': 166,
#  'mint chutney': 50,
#  'dry mustard': 119,
#  'pepper': 2262,
#  'garlic powder': 463,
#  'red onion': 465,
#  'beefsteak tomatoes': 20,
#  'romaine lettuce': 130,
#  'lemon juice': 1493,
#  'sweet pickles': 11,
#  'tilapia fillets': 17,
#  'bread': 166,
#  'belgian endive': 37,
#  'trout filet': 15,
#  'kraft singles': 12,
#  'mayo': 304,
#  'scallions': 865,
#  'water-packed tuna': 7,
#  'multi grain bread': 31,
#  'carrots': 824,
#  'water': 2005,
#  'red pepper flakes': 482,
#  'rustic bread': 10,
#  'ice cubes': 91,
#  'goat cheese': 152,
#  'balsamic vinegar': 238,
#  'watermelon': 37,
#  'milk': 1250,
#  'eggs': 2753,
#  'chicken': 151,
#  'no salt added diced tomatoes': 15,
#  'deep dish pie crust': 42,
#  'pasta': 132,
#  'beef': 20,
#  'sugar syrup': 36,
#  'basil pesto': 78,
#  'ready-to-serve Asian fried rice': 52,
#  'asiago': 32,
#  'meat': 35,
#  'food color': 57,
#  'mustard': 172,
#  'strawberries': 154,
#  'sauvignon blanc': 8,
#  'beetroots': 104,
#  'watercress': 58,
#  'cranberry juice cocktail concentrate': 6,
#  'tangerines': 16,
#  'purple plum': 11,
#  'raisins': 196,
#  'butter': 1997,
#  'pecans': 345,
#  'brown sugar': 997,
#  'mixed greens': 83,
#  'dijon mustard': 382,
#  'red apples': 28,
#  'bell pepper': 463,
#  'mustard greens': 3,
#  'fava beans': 31,
#  'basil': 582,
#  'chili': 201,
#  'fresh corn kernels': 29,
#  'lump crabmeat': 57,
#  'honey': 654,
#  'flour': 2281,
#  'semolina flour': 17,
#  'mozzarella cheese': 166,
#  'pecorino romano cheese': 123,
#  'asparagus': 123,
#  'fresh mushrooms': 378,
#  'pine nuts': 141,
#  'active yeast': 196,
#  'fresh thyme leaves': 484,
#  'fresh rosemary leaves': 200,
#  'leg of lamb': 56,
#  'ribs': 9,
#  'lacinato kale': 39,
#  'spaghetti': 59,
#  'parmesan cheese': 788,
#  'kale': 106,
#  'baby bella mushrooms': 47,
#  'plain nonfat yogurt': 16,
#  'swiss chard': 21,
#  'baking powder': 1200,
#  'rosemary': 189,
#  'parsnip': 51,
#  'baby carrots': 24,
#  'pearl barley': 52,
#  'stock': 77,
#  'sausage': 52,
#  'extra-virgin olive oil': 392,
#  'lamb': 25,
#  'ale': 13,
#  'sherry vinegar': 37,
#  'cayenne pepper': 305,
#  'mint leaves': 276,
#  'lemon': 243,
#  'tahini': 74,
#  'nori': 39,
#  'sesame seeds': 125,
#  'shoyu': 20,
#  'extra firm tofu': 60,
#  'rice vinegar': 213,
#  'short-grain brown rice': 28,
#  'roasted red peppers': 83,
#  'baguette': 65,
#  'olives': 79,
#  'green bell pepper': 314,
#  'yellow bell pepper': 131,
#  'cornmeal': 99,
#  'mascarpone cheese': 40,
#  'won ton wraps': 30,
#  'fresh herbs': 55,
#  'dry couscous': 17,
#  'ground coriander seed': 195,
#  'ground cinnamon': 741,
#  'cooked chicken breasts': 28,
#  'dried cranberries': 79,
#  'cilantro': 781,
#  'almonds': 289,
#  'chicken stock': 273,
#  'quick cooking oats': 29,
#  'fresh sage': 70,
#  'Spice Rub': 92,
#  'heavy cream': 767,
#  'apple': 271,
#  'butternut squash': 104,
#  'saffron threads': 53,
#  'risotto rice': 20,
#  'pancetta': 10,
#  'cooked pasta': 22,
#  'green chile peppers': 241,
#  'picante sauce': 9,
#  'black olives': 101,
#  'frozen corn': 70,
#  'pepper jack cheese': 77,
#  'ground pork': 101,
#  'tomatillos': 47,
#  'serrano peppers': 105,
#  'hominy': 22,
#  'ground cumin': 603,
#  'flour tortillas': 98,
#  'peppercorns': 131,
#  'dill seed': 17,
#  'mustard seeds': 28,
#  'white vinegar': 296,
#  'green tomatoes': 17,
#  'canned white beans': 14,
#  'ciabatta bread': 21,
#  'cipollini onions': 6,
#  'cocktail tomatoes': 235,
#  'curry powder': 69,
#  'russet potatoes': 96,
#  'shrimp': 236,
#  'tofu': 75,
#  'artichoke hearts': 137,
#  'coriander seeds': 118,
#  'lemon zest': 565,
#  'wine': 74,
#  'thai chili': 55,
#  'walnuts': 337,
#  'soy sauce': 380,
#  'broccoli florets': 96,
#  'kalamata olives': 80,
#  'cauliflower florets': 56,
#  'chile powder': 554,
#  'radishes': 54,
#  'chickpeas': 133,
#  'cotija cheese': 27,
#  'vegetable broth': 217,
#  'celery': 376,
#  'baby spinach leaves': 134,
#  'sweet potatoes': 96,
#  'red lentils': 31,
#  'creamy peanut butter': 101,
#  'blackberry jam': 10,
#  'vanilla': 1476,
#  'roasted peanuts': 44,
#  'peanut butter': 83,
#  'asian dressing': 5,
#  'bean sprouts': 32,
#  'napa cabbage': 46,
#  'rice noodles': 38,
#  'shredded mozzarella cheese': 69,
#  'crusty bread': 41,
#  'ground sausage': 56,
#  'egg white': 259,
#  'hard cooked eggs': 63,
#  'leeks': 129,
#  'sirloin tip steak': 5,
#  'beef tenderloin': 15,
#  'coarse grain mustard': 93,
#  'dark brown sugar': 144,
#  'rolled oats': 252,
#  'crystallized ginger': 33,
#  'top round steak': 9,
#  'horseradish': 57,
#  'apple juice': 55,
#  'low fat cottage cheese': 7,
#  'agave syrup': 74,
#  'arrowroot powder': 13,
#  'whole wheat pastry flour': 78,
#  'unbleached flour': 52,
#  'kabocha': 13,
#  'pie crust': 74,
#  'italian sausage': 44,
#  'harissa': 9,
#  'ras el hanout': 9,
#  'red potatoes': 73,
#  'hot cocoa mix': 2,
#  'strong coffee': 34,
#  'fresh ginger root': 684,
#  'fresh shiitake mushrooms': 60,
#  'water chestnuts': 17,
#  'cornstarch': 460,
#  'lettuce leaf': 72,
#  'pork skins': 17,
#  'dark sesame oil': 26,
#  'scallops': 59,
#  '5 spice powder': 34,
#  'toffee': 29,
#  'nutmeg': 571,
#  'yams': 6,
#  'dried thyme': 164,
#  'low-salt chicken broth': 108,
#  'red grapes': 54,
#  'brown rice': 49,
#  'wild rice': 21,
#  'green grapes': 12,
#  'maple syrup': 227,
#  'gorgonzola': 14,
#  'gala apple': 14,
#  'vinaigrette': 18,
#  'bartlett pear': 8,
#  'bacon': 315,
#  'cinnamon': 444,
#  'sweetened coconut flakes': 38,
#  'low fat cream cheese': 41,
#  'graham cracker crumbs': 70,
#  'margarine': 93,
#  'whole cranberry sauce': 22,
#  'bananas': 243,
#  'pineapple': 42,
#  'buckwheat flour': 11,
#  'apple cider': 55,
#  'liquid stevia': 41,
#  'strawberry fruit spread': 23,
#  'baking soda': 885,
#  'blackberries': 51,
#  'peppermint extract': 23,
#  'lime zest': 186,
#  'blueberries': 195,
#  'cherries': 75,
#  'peach': 91,
#  'sparkling water': 28,
#  'brandy': 31,
#  'coconut milk': 133,
#  'soy milk': 9,
#  'shortening': 156,
#  'unsweetened coconut': 49,
#  'port': 4,
#  'fresh fruit': 38,
#  'strawberry yogurt': 5,
#  'stevia': 47,
#  'vanilla pudding mix': 30,
#  'semisweet chocolate': 120,
#  'whipped topping': 85,
#  'skim milk': 132,
#  'angel food cake': 12,
#  'cranberries': 71,
#  'granny smith apple': 64,
#  'cocoa powder': 368,
#  'powdered sugar': 710,
#  'grapeseed oil': 55,
#  'almond flour': 132,
#  'dates': 50,
#  'orange juice concentrate': 26,
#  'white cake mix': 13,
#  'stout beer': 23,
#  'cake flour': 167,
#  'raspberries': 131,
#  'poppy seeds': 61,
#  'gelatin': 22,
#  'plain yogurt': 74,
#  'kahlua': 22,
#  'whipping cream': 102,
#  'cream cheese': 422,
#  'raisin bread': 5,
#  'hot sauce': 149,
#  'corn flakes': 28,
#  'bleu cheese dressing': 14,
#  'skinless boneless chicken breasts': 272,
#  'mussels': 50,
#  'clam juice': 67,
#  'chorizo': 30,
#  'sweet onions': 157,
#  'smoked salmon': 18,
#  'edamame': 31,
#  'shiso leaves': 15,
#  'pork loin chops': 14,
#  'kirsch': 6,
#  'kiwis': 26,
#  'mango': 171,
#  'fennel seeds': 122,
#  'pork loin': 70,
#  'ground sage': 21,
#  'jalapeno': 369,
#  'popcorn': 17,
#  'tequila': 24,
#  'half n half cream': 171,
#  'onion powder': 242,
#  'italian seasoned breadcrumbs': 54,
#  'cornflake crumbs': 10,
#  'lemon wedge': 32,
#  'canned salmon': 7,
#  'parsley flakes': 189,
#  'orange': 77,
#  'lemon-pepper seasoning': 64,
#  'wasabi powder': 6,
#  'sesame oil': 155,
#  'bamboo shoots': 18,
#  'ahi tuna steaks': 28,
#  'jicama': 34,
#  'canned chipotles in adobo': 15,
#  'grapefruit juice': 37,
#  'ground ginger': 249,
#  'onion soup mix': 33,
#  'cabbage': 177,
#  'lean ground beef': 164,
#  'vegetable juice': 14,
#  'beef consomme': 23,
#  'root vegetables': 14,
#  'spring roll wrappers': 25,
#  'coriander': 131,
#  'hoisin sauce': 38,
#  'oyster sauce': 40,
#  'bean thread noodles': 12,
#  'ranch salad dressing mix': 16,
#  'skinless boneless chicken breast halves': 72,
#  'black bean sauce': 13,
#  'grape tomatoes': 61,
#  'low fat cheese': 24,
#  'taco seasoning': 104,
#  'salsa': 143,
#  'chicken broth': 308,
#  'pickled jalapenos': 77,
#  'ears corn': 107,
#  'ground sirloin': 20,
#  'hamburger buns': 53,
#  'ham': 172,
#  'white sandwich bread': 27,
#  'dark beer': 19,
#  'rice': 100,
#  'pork chops': 43,
#  'bay leaf': 358,
#  'skinless boneless chicken thighs': 73,
#  'chili sauce': 49,
#  'green peas': 251,
#  'turkey breast': 10,
#  'salami': 38,
#  'radicchio': 49,
#  'pepperoncini peppers': 36,
#  'sub buns': 86,
#  'low fat shredded cheddar cheese': 20,
#  'packaged no-boil lasagna noodles': 48,
#  'nonfat sour cream': 12,
#  'low fat shredded mexican cheese blend': 12,
#  'pizza sauce': 147,
#  'black beans': 70,
#  'dried black beans': 11,
#  'panko breadcrumbs': 170,
#  'eggplant': 120,
#  'ground cloves': 183,
#  'pumpkin puree': 136,
#  'semi sweet chocolate chips': 119,
#  'peppers': 72,
#  'yellow onion': 223,
#  'cooked bulgur': 33,
#  'round steak': 29,
#  'light soy sauce': 45,
#  'tortilla chips': 86,
#  'shredded cheddar cheese': 303,
#  'cream of mushroom soup': 30,
#  'ramen noodles': 7,
#  'provolone cheese': 47,
#  'roast chicken': 43,
#  'broccoli': 153,
#  'worcestershire sauce': 204,
#  'dry roasted peanuts': 25,
#  'cheese': 128,
#  'bow tie pasta': 32,
#  'sun dried tomato': 100,
#  'petite tomatoes': 9,
#  'wine vinegar': 15,
#  'cauliflower': 134,
#  'canned black beans': 99,
#  'ground beef': 184,
#  'colby jack cheese': 42,
#  'bbq sauce': 164,
#  'chili peppers': 9,
#  'refried beans': 61,
#  'whole wheat flour': 156,
#  'dry sherry': 84,
#  'french bread': 18,
#  'evaporated milk': 42,
#  'turkey meat': 10,
#  'stuffing mix': 16,
#  'ground allspice': 162,
#  'sherry': 20,
#  'mace': 30,
#  'chicken liver': 7,
#  'cumin seeds': 181,
#  'duck leg': 14,
#  'pastry dough': 10,
#  'cooked wide egg noodles': 12,
#  'cream of chicken soup': 43,
#  'canned mushrooms': 37,
#  'horseradish sauce': 4,
#  'ketchup': 162,
#  'hash brown potatoes': 30,
#  'fried onions': 30,
#  'pork hocks': 29,
#  'chicken bouillon granules': 9,
#  'rutabagas': 9,
#  'dried navy beans': 9,
#  'cheddar cheese': 125,
#  'breadcrumbs': 173,
#  'grenadine': 18,
#  'papaya': 20,
#  'light rum': 43,
#  'fontina cheese': 32,
#  'butter flavored shortening': 10,
#  'dried apricots': 30,
#  'egg substitute': 28,
#  'unsweetened applesauce': 90,
#  'chocolate chip cookie': 23,
#  'cantaloupe': 6,
#  'honeydew melon': 11,
#  'whipped cream': 40,
#  'dark chocolate': 78,
#  'angel food cake mix': 28,
#  'crisco': 5,
#  'golden raisins': 46,
#  'eggnog': 18,
#  'rum extract': 7,
#  'graham cracker crust': 15,
#  'cashews': 116,
#  'nutr-grain cereal': 9,
#  'pretzel sticks': 9,
#  'ground sumac': 4,
#  'dried basil': 235,
#  'seasoned salt': 129,
#  'seasonings': 48,
#  'chicken bouillon cube': 16,
#  'processed american cheese': 34,
#  'elbow macaroni': 34,
#  'black sesame seeds': 25,
#  'roast beef': 5,
#  'garlic salt': 33,
#  'ricotta cheese': 132,
#  'swiss cheese': 66,
#  'cooked bacon': 90,
#  'spiced rum': 5,
#  'gruyere cheese': 32,
#  'pomegranate juice': 8,
#  'beer': 35,
#  'black cod': 8,
#  'brie cheese': 22,
#  'chicken legs': 28,
#  'italian dressing': 35,
#  'cooked ham': 37,
#  'taco shells': 17,
#  'currants': 6,
#  'crackers': 27,
#  'chive & onion cream cheese spread': 6,
#  'sharp cheddar': 72,
#  'gf chocolate cake mix': 16,
#  'red food coloring': 42,
#  'cranberry juice': 33,
#  'yellow cake mix': 10,
#  'graham crackers': 24,
#  'lemon pudding mix': 21,
#  'marshmallow creme': 39,
#  'real bacon recipe pieces': 35,
#  'dill pickles': 36,
#  'instant white rice': 40,
#  'cajun seasoning': 31,
#  'canned red beans': 21,
#  'smoked sausage': 10,
#  'candied almonds': 7,
#  'pumpkin pie spice': 31,
#  'almond extract': 83,
#  '0% fat greek yogurt': 46,
#  'coleslaw mix': 40,
#  'white fish fillets': 12,
#  'berries': 24,
#  'instant chocolate pudding mix': 11,
#  'toffee candy bar': 4,
#  'new potatoes': 14,
#  'pattypan squash': 6,
#  'beef top sirloin steak': 39,
#  'pineapple juice': 68,
#  'fish sauce': 68,
#  'canned coconut milk': 54,
#  'turkey tenderloin': 11,
#  'molasses': 130,
#  'canned cannellini beans': 9,
#  'caraway seeds': 31,
#  'sauerkraut': 49,
#  'puff pastry sheets': 45,
#  'dry red wine': 50,
#  'tarragon vinegar': 9,
#  'walnut oil': 6,
#  'apricot preserves': 31,
#  'cardamom pods': 44,
#  'navel oranges': 29,
#  'chicken tenders': 14,
#  'peanut oil': 102,
#  'sorghum': 28,
#  'aged balsamic vinegar': 51,
#  'fleur de sel': 28,
#  'baby beets': 28,
#  'white chocolate': 22,
#  'peppermint candies': 8,
#  'skim milk ricotta': 17,
#  'pita bread': 44,
#  'turkey cutlets': 10,
#  'turmeric powder': 254,
#  'fire roasted canned tomatoes': 17,
#  'grill cheese': 8,
#  'chili oil': 37,
#  'white pepper': 79,
#  'fat-free less-sodium chicken broth': 20,
#  'english muffins': 36,
#  'old bay seasoning': 5,
#  'juice': 77,
#  'pecan pieces': 10,
#  'apple cider vinegar': 283,
#  'tomato juice': 57,
#  'great northern beans': 32,
#  'dried marjoram': 21,
#  'rhubarb': 32,
#  'tea': 38,
#  'milk chocolate': 52,
#  'brown rice flour': 12,
#  'tart apples': 28,
#  'sweet rice flour': 12,
#  'raw sugar': 28,
#  'cooked soba noodles': 9,
#  'Miso Soybean Paste': 38,
#  'ground lamb': 32,
#  'grana padano': 13,
#  'fettuccine': 13,
#  'marinara sauce': 83,
#  'flank steak': 23,
#  'granola cereal': 4,
#  'nut butter': 28,
#  'coke': 2,
#  'vodka': 7,
#  'evaporated cane juice crystals': 16,
#  'rye beer': 11,
#  'crème fraîche': 33,
#  'shredded chicken': 42,
#  'roasted pork': 33,
#  'vermouth': 23,
#  'tomatillo salsa': 22,
#  'angostura bitters': 3,
#  'cognac': 3,
#  'whiskey': 29,
#  'jelly': 17,
#  'hazelnuts': 47,
#  'raw pumpkin seeds': 14,
#  'vanilla ice cream': 45,
#  'instant espresso powder': 20,
#  'chocolate shavings': 15,
#  'nuts': 59,
#  'dessert oats': 36,
#  'self-raising flour': 46,
#  'golden syrup': 8,
#  'Crema Mexicana': 14,
#  'lime wedges': 27,
#  'red cabbage': 38,
#  'halibut': 20,
#  'ranch dressing': 13,
#  'potato chips': 16,
#  'dulce de leche': 7,
#  'low fat greek yogurt': 19,
#  'meatballs': 37,
#  'juniper berries': 17,
#  'gin': 25,
#  'sunflower oil': 25,
#  'pak choi': 10,
#  'garam masala': 143,
#  'paneer': 48,
#  'single cream': 20,
#  'cardamom': 77,
#  'lamb chops': 30,
#  'chili-garlic sauce': 52,
#  'crunchy peanut butter': 6,
#  'light muscovado sugar': 9,
#  'corn syrup': 108,
#  'low fat buttermilk': 44,
#  'evaporated skim milk': 17,
#  'pistachios': 80,
#  'israeli couscous': 22,
#  'cooked rice': 45,
#  'tomato paste': 273,
#  'rack of lamb': 34,
#  'syrah': 16,
#  'skirt steak': 23,
#  'poblano pepper': 42,
#  'chocolate milk': 19,
#  'candied orange peel': 7,
#  'monterey jack cheese': 109,
#  'turkey pepperoni': 8,
#  'star anise': 29,
#  'anaheim chiles': 15,
#  'anise seeds': 43,
#  'lemongrass': 49,
#  'fuji apple': 18,
#  'lemonade': 2,
#  'amaretto liqueur': 2,
#  'coconut rum': 2,
#  'frisee': 6,
#  'pumpkin': 23,
#  'lemon lime pop': 4,
#  'cherry juice': 4,
#  'candy cane': 39,
#  'cooked pork': 11,
#  'yukon gold potatoes': 38,
#  'tortilla': 7,
#  'mozzarella balls': 28,
#  'chocolate chunks': 27,
#  'sourdough starter': 32,
#  'high gluten flour': 6,
#  'mixed veggies': 55,
#  'luncheon meat': 8,
#  'short grain rice': 8,
#  'shredded mexican cheese blend': 35,
#  'lean bacon': 8,
#  'pernod': 11,
#  'bay scallops': 31,
#  'ginger beer': 3,
#  'blanched almonds': 47,
#  'steel cut oats': 9,
#  'dried fruit': 32,
#  'chocolate chips': 91,
#  'crispy rice cereal': 29,
#  'merlot': 8,
#  'caramel topping': 36,
#  'phyllo cups': 18,
#  'filet mignon steaks': 18,
#  'dried dill': 34,
#  'bacon drippings': 25,
#  'lobster meat': 13,
#  'canned crabmeat': 13,
#  'clams': 33,
#  'Low Moisture Part-Skim Mozzarella Cheese': 12,
#  'velveeta cheese': 19,
#  'spaghetti sauce': 50,
#  'penne pasta': 26,
#  'deli turkey': 13,
#  'pizza dough': 46,
#  'beef tenderloin steaks': 6,
#  'littleneck clams': 11,
#  'bologna': 31,
#  'sweetened condensed milk': 54,
#  'raspberry jam': 14,
#  'roquefort cheese': 19,
#  'white cheddar cheese': 28,
#  'gemelli': 16,
#  'dried sage': 27,
#  'white onion': 45,
#  'sake': 42,
#  'mirin': 8,
#  'cooked sushi rice': 8,
#  'white rice': 42,
#  'gluten-free flour': 30,
#  'xanthan gum': 55,
#  'corned beef brisket': 10,
#  'pork n beans': 23,
#  'pork sausage': 4,
#  'lean ground turkey': 140,
#  'turkey sausages': 39,
#  'italian seasoning': 167,
#  'popcorn kernels': 1,
#  'oysters': 19,
#  'bouillon cube': 19,
#  'seafood seasoning': 19,
#  'orzo pasta': 10,
#  'dried brown lentils': 82,
#  'red enchilada sauce': 37,
#  'pineapple rings': 4,
#  'english cucumbers': 16,
#  'apricots': 6,
#  'cornmeal mix': 7,
#  'shichimi togarashi': 10,
#  'jasmine rice': 19,
#  'egg noodles': 42,
#  'hungarian paprika': 73,
#  'cream of tartar': 47,
#  'm&m candy': 32,
#  'dark corn syrup': 10,
#  'vanilla bean': 92,
#  'canned garbanzo beans': 49,
#  'canned tuna': 7,
#  'tri-color pasta': 7,
#  'turkey': 49,
#  'portabella mushroom caps': 32,
#  'chardonnay': 3,
#  'kumquats': 10,
#  'stick margarine': 9,
#  'tomato puree': 13,
#  'herbes de provence': 25,
#  'dutch process cocoa powder': 16,
#  'fat-free vanilla yogurt': 27,
#  'chai spice': 27,
#  'coconut extract': 27,
#  'mango extract': 27,
#  'liquid smoke': 40,
#  'oil packed sun dried tomatoes': 17,
#  'low sodium chicken stock': 28,
#  'corn kernels': 30,
#  'fuyu persimmons': 11,
#  'milk powder': 50,
#  'canned beef broth': 65,
#  'apple pie filling': 8,
#  'icing': 47,
#  'pepitas': 64,
#  'blue cheese': 41,
#  'coconut cream': 7,
#  'coconut water': 3,
#  'chile paste': 37,
#  'lean pork tenderloin': 32,
#  'fig preserves': 11,
#  'low fat milk': 16,
#  'natural spices': 2,
#  'peanut': 28,
#  'quinoa': 111,
#  'yogurt': 81,
#  'fingerling potatoes': 11,
#  'cannellini beans': 13,
#  'wasabi paste': 19,
#  'basmati rice': 40,
#  'italian cheese blend': 7,
#  'smoked paprika': 112,
#  'ground chipotle chile pepper': 50,
#  'orange marmalade': 10,
#  'baby-back ribs': 12,
#  'dried onion': 18,
#  'celery seed': 25,
#  'corned beef': 21,
#  'diced ham': 36,
#  'steak sauce': 13,
#  'instant coffee granules': 47,
#  'rye bread': 16,
#  'croutons': 17,
#  'silken tofu': 16,
#  'imitation crabmeat': 12,
#  'shell pasta': 48,
#  'teriyaki sauce': 5,
#  'quick cooking tapioca': 11,
#  'dried garlic': 11,
#  'bread flour': 42,
#  'chili beans': 22,
#  'canned diced tomatoes': 34,
#  'light beer': 22,
#  'cookie mix': 7,
#  'peach nectar': 15,
#  'texas toast': 7,
#  'part-skim mozzarella cheese': 57,
#  'pepperoni': 15,
#  'tomato soup': 21,
#  'baking mix': 42,
#  'naan bread': 43,
#  'fresh bay leaf': 43,
#  'cinnamon sticks': 52,
#  'mango chutney': 38,
#  'dried mint': 41,
#  'pork spareribs': 4,
#  'white chocolate chips': 22,
#  'corn': 54,
#  'canned kidney beans': 38,
#  'canned pinto beans': 23,
#  'marshmallows': 63,
#  'chocolate hazelnut spread': 5,
#  'dessert shells': 5,
#  'chocolate sauce': 5,
#  'prosciutto': 22,
#  'filo pastry': 30,
#  'no calorie sweetener': 12,
#  'splenda brown sugar blend': 9,
#  'bread cubes': 20,
#  'matzo': 7,
#  'sausage links': 27,
#  'spiral pasta': 9,
#  'corn chips': 24,
#  'microwave popcorn': 5,
#  'deli ham': 10,
#  'pork shoulder roast': 21,
#  'haddock': 14,
#  'whole wheat tortillas': 12,
#  'creole seasoning': 4,
#  'cheese tortellini': 11,
#  'summer squash': 26,
#  'bibb lettuce leaves': 14,
#  'slivered almonds': 65,
#  'hummus': 24,
#  'lavash': 13,
#  'chocolate syrup': 3,
#  'gum drop': 20,
#  'sprinkles': 55,
#  'rib tips': 25,
#  'licorice twist': 20,
#  'pink himalayan salt': 38,
#  'butterscotch chips': 18,
#  'browning sauce': 8,
#  'nilla wafers': 9,
#  'lime gelatin': 20,
#  'quinces': 8,
#  'lamb shoulder': 8,
#  'rigatoni pasta': 13,
#  'green apples': 24,
#  'vanilla yogurt': 4,
#  'chocolate wafer cookies': 10,
#  'pineapple in juice': 20,
#  'crescent rolls': 15,
#  'bone-in chicken thighs': 16,
#  'black tea bags': 20,
#  'coconut': 63,
#  'sweet pickle juice from the jar': 14,
#  'candied cherries': 14,
#  'splenda': 9,
#  'canned great northern beans': 13,
#  'beef stock': 26,
#  'beef chuck roast': 37,
#  'skinless chicken drumsticks': 6,
#  'skinless bone-in chicken thighs': 24,
#  'whole wheat bread crumbs': 27,
#  'seasoning mix': 36,
#  'pimento cheese spread': 7,
#  'chicken bouillon': 4,
#  'celery salt': 21,
#  'turkey drumsticks': 12,
#  'sunflower seed butter': 31,
#  'coconut oil': 209,
#  'coconut flour': 51,
#  'ground bison': 12,
#  'curry paste': 63,
#  'frozen spinach': 42,
#  'challah bread': 7,
#  'peas and carrots': 24,
#  'almond milk': 137,
#  'greek yogurt': 161,
#  'medjool dates': 15,
#  'chia seeds': 36,
#  'pork ribs': 37,
#  'ghee': 100,
#  'rajma masala': 13,
#  'unsweetened shredded coconut': 66,
#  'triple sec': 9,
#  'peanut sauce': 14,
#  'sriracha': 50,
#  'allspice berries': 5,
#  'low fat natural yogurt': 27,
#  'nonfat cool whip': 23,
#  'white miso': 8,
#  'brussels sprouts': 85,
#  'malt mix': 17,
#  'bourbon': 39,
#  'coconut butter': 4,
#  'cream cheese frosting': 13,
#  'spinach tortellini': 12,
#  'sweetened shredded coconut': 6,
#  'limoncello': 3,
#  'biscuits': 13,
#  'cooked couscous': 16,
#  'chipotle': 16,
#  'green food coloring': 10,
#  'blood orange zest': 12,
#  'cooked orzo': 9,
#  'slaw dressing': 26,
#  'chicken pieces': 13,
#  'sugar free apricot preserves': 3,
#  'cream cheese block': 32,
#  'unsweetened chocolate': 43,
#  'salted butter': 54,
#  'hotdog': 44,
#  'hot dog buns': 14,
#  'soba noodles': 12,
#  'safflower oil': 31,
#  'oat flour': 18,
#  'turnip': 32,
#  'hemp seeds': 22,
#  'nutritional yeast': 53,
#  'kelp': 12,
#  'shredded cheese': 28,
#  'coconut sugar': 55,
#  'brownie mix': 9,
#  'candy melts': 18,
#  'sunflower seeds': 40,
#  'cereal': 13,
#  'strawberry jell-o': 3,
#  'linguine': 29,
#  'fenugreek seeds': 40,
#  'mango powder': 30,
#  'cinnamon sugar': 4,
#  'whole wheat pasta': 11,
#  'wheat bran': 31,
#  'celery root': 32,
#  'strip steak': 26,
#  'rose water': 26,
#  'chocolate glaze': 12,
#  'dark chocolate chips': 64,
#  'balsamic glaze': 21,
#  'tater tots': 5,
#  'pineapple chunks': 18,
#  'chocolate mint': 6,
#  'grand marnier': 9,
#  'wheat berries': 7,
#  'dried kidney beans': 7,
#  'guar gum': 4,
#  'mounds': 6,
#  'chocolate ice cream': 4,
#  'ground chicken': 10,
#  'artichokes': 18,
#  'cottage cheese': 15,
#  'part skim ricotta cheese': 12,
#  'pimento stuffed olives': 12,
#  'lemon curd': 12,
#  'instant yeast': 12,
#  'lemon oil': 12,
#  'pretzel rolls': 21,
#  'mixed mushrooms': 16,
#  'dried porcini mushrooms': 16,
#  'salad oil': 18,
#  'peanut butter chips': 20,
#  ...}

# %%
for i in ingredients:
    for j in ingredients:
        recipe_pmi.loc[i,j] = df_pmi.loc[i,j]/(sum_dict[i] * sum_dict[j])

# %%
recipe_pmi
# Out:
#                         white wine vinegar  salt and pepper  \
# white wine vinegar                0.000000         0.000021
# salt and pepper                   0.000021         0.000000
# low fat sour cream                0.000458         0.000026
# buttermilk                        0.000065         0.000004
# fresh tarragon                    0.000366         0.000021
# ...                                    ...              ...
# potato flakes                     0.000000         0.000108
# 85 percent ground beef            0.000000         0.000108
# queso dip                         0.000000         0.000098
# erythritol                        0.000000         0.000000
# hazelnut meal                     0.000000         0.000000
#
#                         low fat sour cream  buttermilk  fresh tarragon  \
# white wine vinegar                0.000458    0.000065        0.000366
# salt and pepper                   0.000026    0.000004        0.000021
# low fat sour cream                0.000000    0.000080        0.000227
# buttermilk                        0.000080    0.000000        0.000064
# fresh tarragon                    0.000227    0.000064        0.000000
# ...                                    ...         ...             ...
# potato flakes                     0.000000    0.000000        0.000000
# 85 percent ground beef            0.000000    0.000000        0.000000
# queso dip                         0.000000    0.000000        0.000000
# erythritol                        0.000000    0.000000        0.000000
# hazelnut meal                     0.000000    0.000000        0.000000
#
#                         olive oil  low fat mayonnaise  chicken breasts  \
# white wine vinegar       0.000032            0.000370         0.000135
# salt and pepper          0.000018            0.000041         0.000038
# low fat sour cream       0.000010            0.000458         0.000168
# buttermilk               0.000006            0.000065         0.000024
# fresh tarragon           0.000024            0.000183         0.000134
# ...                           ...                 ...              ...
# potato flakes            0.000000            0.000000         0.000000
# 85 percent ground beef   0.000000            0.000000         0.000000
# queso dip                0.000000            0.000000         0.000640
# erythritol               0.000000            0.000000         0.000000
# hazelnut meal            0.000000            0.000000         0.000000
#
#                          avocado    chives  ...  rooibos  \
# white wine vinegar      0.000052  0.000088  ...      0.0
# salt and pepper         0.000015  0.000030  ...      0.0
# low fat sour cream      0.000064  0.000109  ...      0.0
# buttermilk              0.000027  0.000031  ...      0.0
# fresh tarragon          0.000026  0.000044  ...      0.0
# ...                          ...       ...  ...      ...
# potato flakes           0.000000  0.000000  ...      0.0
# 85 percent ground beef  0.000000  0.000000  ...      0.0
# queso dip               0.000000  0.000000  ...      0.0
# erythritol              0.000000  0.000000  ...      0.0
# hazelnut meal           0.000000  0.000000  ...      0.0
#
#                         low sodium beef broth  cooked macaroni pasta   tempeh  \
# white wine vinegar                        0.0                0.00000  0.00000
# salt and pepper                           0.0                0.00012  0.00000
# low fat sour cream                        0.0                0.00000  0.00000
# buttermilk                                0.0                0.00000  0.00016
# fresh tarragon                            0.0                0.00000  0.00000
# ...                                       ...                    ...      ...
# potato flakes                             0.0                0.00000  0.00000
# 85 percent ground beef                    0.0                0.00000  0.00000
# queso dip                                 0.0                0.00000  0.00000
# erythritol                                0.0                0.00000  0.00000
# hazelnut meal                             0.0                0.00000  0.00000
#
#                         canned beans  potato flakes  85 percent ground beef  \
# white wine vinegar               0.0       0.000000                0.000000
# salt and pepper                  0.0       0.000108                0.000108
# low fat sour cream               0.0       0.000000                0.000000
# buttermilk                       0.0       0.000000                0.000000
# fresh tarragon                   0.0       0.000000                0.000000
# ...                              ...            ...                     ...
# potato flakes                    0.0       0.000000                0.010000
# 85 percent ground beef           0.0       0.010000                0.000000
# queso dip                        0.0       0.000000                0.000000
# erythritol                       0.0       0.000000                0.000000
# hazelnut meal                    0.0       0.000000                0.000000
#
#                         queso dip  erythritol  hazelnut meal
# white wine vinegar       0.000000         0.0            0.0
# salt and pepper          0.000098         0.0            0.0
# low fat sour cream       0.000000         0.0            0.0
# buttermilk               0.000000         0.0            0.0
# fresh tarragon           0.000000         0.0            0.0
# ...                           ...         ...            ...
# potato flakes            0.000000         0.0            0.0
# 85 percent ground beef   0.000000         0.0            0.0
# queso dip                0.000000         0.0            0.0
# erythritol               0.000000         0.0            0.0
# hazelnut meal            0.000000         0.0            0.0
#
# [1231 rows x 1231 columns]

# %%
recipe_pmi.to_csv('recipe_pmi.csv', index = False)
